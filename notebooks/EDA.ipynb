# %%
# !pip install nbformat --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\natha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# !pip install plotly
import plotly.io as pio
pio.renderers.default = "notebook"  # Or use "iframe" if "notebook" doesn't work
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\natha\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from plotly) (24.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\natha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
car_advertisement = pd.read_csv('vehicles_us.csv')

# %%
car_advertisement.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
car_advertisement.isnull().sum() #checking for missing values
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
car_advertisement = car_advertisement.dropna()
car_advertisement = car_advertisement.dropna(axis=1) #dropping columns with missing values

# %%
car_advertisement.isnull().sum() #Finding the sum of missing values.
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
car_advertisement.duplicated().sum() #checking for duplicated values.
# Out:
# np.int64(0)

# %%
fig_grouped_histogram = px.histogram(
    car_advertisement, 
    x='price', 
    color='type',  # Group by vehicle type
    barmode='group',  # Options: 'group' or 'overlay'
    nbins=5, 
    title='Price Distribution by Vehicle Type', 
    labels={'price': 'Price ($)', 'type': 'Vehicle Type'}
)
fig_grouped_histogram.show()
# Out:
# <div>                            <div id="e0005560-54da-49c5-b6c8-cb38f237173b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0005560-54da-49c5-b6c8-cb38f237173b")) {                    Plotly.newPlot(                        "e0005560-54da-49c5-b6c8-cb38f237173b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Vehicle Type=sedan\u003cbr\u003ePrice ($)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sedan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sedan","nbinsx":5,"offsetgroup":"sedan","orientation":"v","showlegend":true,"x":[14990,11200,10800,6995,9799,7900,15750,5500,5500,4995,4995,8900,14900,6995,11998,7995,3900,14495,11000,64000,25545,17500,4959,5495,4995,4995,5999,4900,5999,3999,19451,1500,6195,6995,6500,9900,2400,13500,19451,4999,4995,4995,3950,3999,7850,700,24995,4995,4347,24199,2900,7300,13249,3200,5707,3850,23777,10800,10500,2200,1,1,1,1,1,1,21988,4495,6000,1,1,1,1,1,12000,9500,9900,8499,8499,7750,8499,1,1,1,1,1,2350,1,1,1,1,3000,1,1,13795,7900,6500,9995,14495,1,1,5707,9000,3000,1,1,1,1,1,1,1,4500,1,1,12995,1,1,1,9900,1,1,4790,6000,4500,14665,21988,5495,4500,5707,5707,1,1,5000,6995,12800,7000,5200,25000,5200,13500,5000,4800,6900,10495,7900,384,8690,6800,18750,3300,7495,5995,6500,8499,8499,4500,3000,9500,1,7995,13500,9975,7500,4950,18958,4950,14750,1,3800,13997,1,1,1,6950,1,15000,12500,17999,7995,5500,17999,19995,13997,2995,5900,8995,1,17999,5500,5500,10300,5999,19995,5500,1,1,1,11999,4995,13995,13995,25995,13995,11999,15995,1500,1499,3695,6500,13500,6000,21988,11971,11500,4500,14750,7499,12995,9990,15925,1,14750,1,8200,1,3300,384,12000,5500,1,14900,7450,4197,12500,6000,7500,5700,9999,23995,13500,8988,12480,3400,14750,7999,12599,14495,9998,10988,7999,6000,8200,9799,17000,8690,3450,7950,4197,17977,23500,10500,16900,13500,8497,20000,5707,17995,3950,11950,10800,1,17999,3397,4300,13800,14998,16490,8500,10300,5900,6900,4950,11997,15590,7000,17999,8000,7995,3850,6900,7995,1,1,1,11998,3000,1000,8000,6399,14885,6495,3500,8690,8000,8497,4800,12000,3500,1,2600,15900,10800,11995,3000,24199,4500,9200,21000,7300,16258,10500,7995,10800,3650,3200,8500,5900,2200,6995],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Vehicle Type=SUV\u003cbr\u003ePrice ($)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SUV","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SUV","nbinsx":5,"offsetgroup":"SUV","orientation":"v","showlegend":true,"x":[15990,12990,13990,12500,5000,3890,11499,5100,1900,4826,8995,3995,5500,10999,11995,15995,6995,14995,12990,11950,16950,22914,24495,7800,7995,1500,3750,7995,9100,22914,14999,5500,30000,4500,12995,4000,5999,7997,4000,34275,11675,24995,15900,4975,6995,10995,8600,14900,9500,9950,21900,8995,47995,16499,4995,8995,3995,14900,6300,19988,2000,19900,7900,6500,4900,12995,13000,18500,12900,13750,5900,13995,35900,1999,7999,10500,4995,6750,10000,6800,21995,21995,14900,7950,11500,10900,5995,19791,3895,2000,7995,22990,11900,8450,16995,6995,10995,4995,13250,9950,8495,10995,13890,6995,11995,13995,13450,12999,5995,1500,28950,3990,11900,25900,13500,15995,12500,5000,2500,8500,4500,9500,7995,11450,14999,6800,16925,13985,12000,21477,4000,6300,9995,13995,15000,1500,4950,5195,14990,7600,17950,9950,13395,11880,28000,14995,2000,21500,23990,29900,28250,42995,11500,15250,17995,15995,17500,7495,8000,11500,27500,8000,11900,13900,16299,4000,17995,7990,47500,13995,6399,11900,3800,44495,10994,60774,30029,4500,19991,13600,4395,21988,20617,2300,12600,14995,55990,18995,22905,33311,3700,7990,24699,3500,23991,46500,31552,21756,20994,14900,14900,8900,10995,17995,7800,5500,16400,11200,7988,4200,11800,11800,60774,16995,27243,390 ...

# %% [markdown]
# #The histogram reveals that trucks are the most popular vehicle type among customers, as indicated by the tallest bar in the chart. This suggests that a significant portion of the market demand is for trucks compared to other types of vehicles like sedans, SUVs, or vans.

# %%
fig_scatter_price_odometer = px.scatter(
    car_advertisement, 
    x='odometer',  # X-axis variable
    y='price',  # Y-axis variable
    title='Scatterplot: Price vs Odometer',
    labels={'odometer': 'Odometer (miles)', 'price': 'Price ($)'},
    color='type',  # Color by vehicle type
    hover_data=['model', 'paint_color']  # Extra details on hover
)
fig_scatter_price_odometer.show()
# Out:
# <div>                            <div id="de13d343-8cd6-47a9-929b-e87d7200ae52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("