# %%
# !pip install nbformat --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\natha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# !pip install plotly
import plotly.io as pio
pio.renderers.default = "notebook"  # Or use "iframe" if "notebook" doesn't work
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\natha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
car_advertisement = pd.read_csv('vehicles_us.csv')

# %%
car_advertisement.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
car_advertisement.isnull().sum() #checking for missing values
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
car_advertisement = car_advertisement.dropna()
car_advertisement = car_advertisement.dropna(axis=1) #dropping columns with missing values

# %%
car_advertisement.isnull().sum() #Finding the sum of missing values.
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
car_advertisement.duplicated().sum() #checking for duplicated values.
# Out:
# np.int64(0)

# %%
fig_grouped_histogram = px.histogram(
    car_advertisement, 
    x='price', 
    color='type',  # Group by vehicle type
    barmode='group',  # Options: 'group' or 'overlay'
    nbins=5, 
    title='Price Distribution by Vehicle Type', 
    labels={'price': 'Price ($)', 'type': 'Vehicle Type'}
)
fig_grouped_histogram.show()
# Out:
# <div>                            <div id="e0005560-54da-49c5-b6c8-cb38f237173b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0005560-54da-49c5-b6c8-cb38f237173b")) {                    Plotly.newPlot(                        "e0005560-54da-49c5-b6c8-cb38f237173b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Vehicle Type=sedan\u003cbr\u003ePrice ($)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sedan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sedan","nbinsx":5,"offsetgroup":"sedan","orientation":"v","showlegend":true,"x":[14990,11200,10800,6995,9799,7900,15750,5500,5500,4995,4995,8900,14900,6995,11998,7995,3900,14495,11000,64000,25545,17500,4959,5495,4995
# ...

# %% [markdown]
# A histogram diagram showing the distribution of vehicle type and its prices.

# %%
fig_scatter_year_price = px.scatter(
    car_advertisement, 
    x='model_year', 
    y='price',
    title='Scatterplot: Model Year vs Price',
    labels={'model_year': 'Model Year', 'price': 'Price ($)'},
    color='paint_color',  # Differentiate points by paint color
    size='odometer',  # Bubble size proportional to odometer reading
    hover_data=['model', 'days_listed']  # Show additional info
)
fig_scatter_year_price.show()
# Out:
# <div>                            <div id="707d0eb3-6a91-4053-bca0-326b88f6e1d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("707d0eb3-6a91-4053-bca0-326b88f6e1d3")) {                    Plotly.newPlot(                        "707d0eb3-6a91-4053-bca0-326b88f6e1d3",                        [{"customdata":[["chrysler 300",15],["honda pilot",68],["chevrolet silverado 1500",38],["gmc yukon",24],["ford f-150",1],["dodge charger",73],["chevrolet silverado",38],["toyota rav4",24],["chevrolet silverado 1500",53],["chevrolet silverado 1500 crew",18],["jeep wrangler",112],["chevrolet silverado 1500",13],["chevrolet silverado 1500 crew",64],["toyota tacoma",30],["ford f-350 sd",30],["toyota tacoma",8],["gmc sierra 1500",23],["toyota camry",24],["jeep grand ch
# ...
